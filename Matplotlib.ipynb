# %%
#Matplotlib used for data visualization

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
#functional method to create plot

# %%
plt.plot(x,y,'r-')
#add axis
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
#if you are not in jupyter use plt.show()
# Out:
# Text(0.5,1,'Title')

# %%
#putting multi plots

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#object oriented
fig= plt.figure()

axes= fig.add_axes([0.1,0.1,0.8,0.8]) # passing list here
axes.plot(x,y)
axes.set_xlabel('x Label')
axes.set_ylabel('y label')
axes.set_title('title')
# Out:
# Text(0.5,1,'title')

# %%
#putting 2 sets of image on object oriented canvas

# %%
fig =plt.figure()

axes1= fig.add_axes([0.1,0.1,0.8,0.8]) #left, bottom, width and height

axes2 = fig.add_axes([0.5,0.15,0.4,0.3]) #percentage values

axes1.plot(x,y)

axes2.plot(y,x)

# %%
#matplotlib part 2

# %%
#creating subplots using OO

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
#axes.plot(x,y)
axes[0].plot(x,y)
axes[0].set_title("First")
axes[1].plot(y,x)
#plt.tight_layout()

# %%
#Figure Size and DPI

fig,axes= plt.subplots(nrows=2, ncols=1, figsize=(8,2))
axes[0].plot(x,y)

axes[1].plot(y,x)
#axes=fig.add_axes([0,0,1,1])
#axes.plot(x,y)
plt.tight_layout()

# %%
#to save figure in pdf, png etc

# %%
fig

# %%
fig.savefig('my_picture.png')

# %%
fig =plt.figure()

axes= fig.add_axes([0.1,0.1,0.8,0.8]) #left, bottom, width and height

axes.plot(x,x**2, label='X Square')

#adding legends

axes.plot(x,x**3, label = 'X Cubed')

axes.legend(loc=(0.1,0.1)) #give location of legend by no or set of points

# %%
#matplotlib part3

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='#FF8C00', lw=1 , alpha=0.4, ls=':', marker='o', markersize='20',
       markerfacecolor='purple', markeredgewidth=3, markeredgecolor='green') #adding colors #adding RGB hex codes
#alpha adds transparency
#line width and line style -check linestyles in notebook
#marker marks set of points

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
len(x)
# Out:
# 11

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='#FF8C00', lw=3 , alpha=0.6, ls=':') 
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %%
#specialized plot types

# %%
#scatter plots

plt.scatter(x,y)

# %%
from random import sample

# %%
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 10.,  11.,  13.,  10.,   5.,  11.,   7.,   9.,  17.,   7.]),
#  array([   4. ,  103.5,  203. ,  302.5,  402. ,  501.5,  601. ,  700.5,
#          800. ,  899.5,  999. ]),
#  <a list of 10 Patch objects>)

# %%
#boxplot

data= [np.random.normal(0,std,100) for std in range(1,4)]

plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0xa6c3b70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xa6d1270>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xa6d1a50>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xa6d1770>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0xa6c3d50>,
# ...
#   <matplotlib.lines.Line2D at 0xa6e21d0>]}
