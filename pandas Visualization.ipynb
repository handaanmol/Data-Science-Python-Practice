# %%
#pandas built in visualization

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd
# %matplotlib inline

# %%
df1=pd.read_csv('df1', index_col=0)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# 2000-01-06 -0.891165  0.741147  0.237482 -1.501909
# 2000-01-07  1.111132  0.287674  0.183012  1.359046
# 2000-01-08 -1.290901 -0.549247 -0.825183  0.328940
# 2000-01-09 -1.689655  0.818016  1.137704  0.334530
# 2000-01-10  0.416580 -1.188162  0.753229 -0.728224
# 2000-01-11  0.328968 -1.087598  1.352827  0.997733
# 2000-01-12  0.263585 -0.187620 -1.083475 -0.099250
# 2000-01-13 -0.293007 -0.813710  2.726993  1.869973
# 2000-01-14  1.108678 -0.339782  1.923170  0.156140
# 2000-01-15  1.818886  0.979137  0.554317  0.564793
# 2000-01-16  1.027913  0.419564  0.684419 -2.063248
# 2000-01-17 -0.016772  0.078902 -0.271826  1.955717
# ...

# %%
df2=pd.read_csv('df2')

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
#getting histograms directly from pandas

# %%
df1['A'].hist(bins=20) #calls matplotlib under the hood

# %%
df1['A'].plot(kind='hist')

# %%
#another way of calling plot

# %%
df1['A'].plot.hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar(stacked=True) #stack creates one plot on top of one another

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(x=df1.index,y='B', figsize=(12,3), lw=1)

# %%
df1.plot.scatter(x='A',y='B',c='C', cmap='coolwarm', s=df1['C']*100)
# Out:
# c:\users\handa\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#boxplot

# %%
df2.plot.box()

# %%
#for bivariate data

# %%
df=pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df
# Out:
#             a         b
# 0    0.589379 -0.499205
# 1    1.041869 -0.993735
# 2   -0.039762 -0.910423
# 3    0.512685  0.412174
# 4   -0.023746 -1.107484
# 5   -0.219797  1.727831
# 6    0.713705  0.784094
# 7    0.486102 -0.730835
# 8    0.176117 -1.252565
# 9   -0.447511 -0.004404
# 10  -1.906234 -0.135953
# 11  -2.069219  0.072654
# 12  -0.550180  0.503885
# 13  -1.879661  0.772352
# 14  -1.286832 -0.954176
# 15  -0.647503 -1.825318
# 16   1.888171  0.451347
# 17  -0.616252  0.288099
# 18   0.068805  0.331708
# 19  -0.402610 -1.700154
# 20  -0.735276  0.032230
# 21   0.133260 -0.067158
# 22  -0.476156  1.157229
# 23   0.320252  0.290550
# 24  -2.109965  0.766327
# 25   1.312838  2.313031
# 26   1.279114 -0.728067
# 27   1.123157 -0.132899
# 28   1.880642 -0.894452
# 29  -0.311972 -1.126142
# ..        ...       ...
# 970 -1.347863 -0.082179
# 971 -1.676745  1.333144
# 972 -0.191602  0.822139
# 973 -0.058650 -0.221602
# 974 -0.734060  1.468764
# 975 -0.959329 -1.426224
# ...

# %%
df.plot.hexbin(x='a',y='b', gridsize=25)

# %%
#kde

# %%
df2['a'].plot.kde()
df2['a'].plot.density()
df2.plot.density()
